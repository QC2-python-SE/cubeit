# %%
from cubeit.register import _QuantumRegister as QuantumRegister, QuantumState
import cubeit.visualisation as vs
import importlib
importlib.reload(vs)
import numpy as np
import matplotlib.pyplot as plt

# %%
state = QuantumRegister()
vs.print_state(state)

print(state.state.state[0].real)

vs.plot_bloch_sphere(state)
# Out:
# 1.000|00⟩
# 1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       2 vs.print_state(state)
#       4 print(state.state.state[0].real)
# ----> 6 vs.plot_bloch_sphere(state)
#
# File c:\Users\daani\OneDrive - University College London\CDT_softeng_coursework\cubeit\cubeit\cubeit\visualisation.py:101, in plot_bloch_sphere(system)
#      99 state_vectors = []
#     100 for i in system.state.state:
# --> 101     state_vectors.append(QuantumState([i]))
#     103 for i in range(num_qubits):
#     104     ax = fig.add_subplot(1, num_qubits, i + 1, projection='3d')
#
# File c:\Users\daani\OneDrive - University College London\CDT_softeng_coursework\cubeit\cubeit\cubeit\register.py:29, in QuantumState.__init__(self, state_vector, num_qubits)
#      27     self.state = state_vector / norm
#      28 else:
# ...
