# %% [markdown]
# # Cubeit quantum circuit simulator - a tutorial
#
# Need to cover:
#
# - Bloch sphere visualisation and what it means
# - Circuit vis
# - Different gates and how to enter them
# - Noise models
# - Export - save figs - etc.
